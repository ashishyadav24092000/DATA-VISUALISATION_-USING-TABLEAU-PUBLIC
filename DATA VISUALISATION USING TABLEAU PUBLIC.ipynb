# %% [markdown]
# ## For having a look at my data visualisation vizzes go to below link :
#
# # https://public.tableau.com/app/profile/ashish.kumar.yadav/viz

# %%
import pandas as pd

# %%
data_frame  = pd.read_csv('/home/ashish/DATA_Visualisation/P12-OfficeSupplies.csv')
data_frame
# Out:
#       OrderDate   Region      Rep     Item  Units  Unit Price
# 0    4-Jul-2014     East  Richard  Pen Set     62        4.99
# 1   12-Jul-2014     East     Nick   Binder     29        1.99
# 2   21-Jul-2014  Central   Morgan  Pen Set     55       12.49
# 3   29-Jul-2014     East    Susan   Binder     81       19.99
# 4    7-Aug-2014  Central  Matthew  Pen Set     42       23.95
# 5   15-Aug-2014     East  Richard   Pencil     35        4.99
# 6   24-Aug-2014     West    James     Desk      3      275.00
# 7    1-Sep-2014  Central    Smith     Desk      2      125.00
# 8   10-Sep-2014  Central     Bill   Pencil      7        1.29
# 9   18-Sep-2014     East  Richard  Pen Set     16       15.99
# 10  27-Sep-2014     West    James      Pen     76        1.99
# 11   5-Oct-2014  Central   Morgan   Binder     28        8.99
# 12  14-Oct-2014     West   Thomas   Binder     57       19.99
# 13  22-Oct-2014     East  Richard      Pen     64        8.99
# ...

# %% [markdown]
# # So this is our primary data on which we have performed basic Tableau Charts operations using the Tableau Public Software.
#
# ## The snippets of the visualisation and the analysis is shown below :

# %% [markdown]
# # 1.  Data Visualisation for our file P12OfficeSupplies.csv through -----> Bar Graphs using the tool or software package Tableau Public.

# %% [markdown]
# ![Bar_Graph_1.png](attachment:Bar_Graph_1.png)

# %% [markdown]
# ---> It depicts the total number of units sold in East region as per our dataset.

# %% [markdown]
# ![bar_graph_2.png](attachment:bar_graph_2.png)

# %% [markdown]
# ---> It depicts the total number of units sold in central region as per our dataset.

# %% [markdown]
# ![bar_graph_3.png](attachment:bar_graph_3.png)

# %% [markdown]
# ---> It depicts the total number of units sold in East region as per our dataset.

# %% [markdown]
# # 2.  Data Visualisation for our file P12OfficeSupplies.csv through -----> Bubble chart using tool or software package Tableau Public.

# %% [markdown]
# ![bubble_graph_1.png](attachment:bubble_graph_1.png)

# %% [markdown]
# ---> It depicts the total number of units sold,as per different regions on the basis of our dataset.

# %% [markdown]
# # 3. Data Visualisation for our file P12OfficeSupplies.csv through ----->  using the pie chart  tool or software package Tableau Public.

# %% [markdown]
# ![Pir_chart_1.png](attachment:Pir_chart_1.png)

# %% [markdown]
# ---> It depicts the total number of units sold in Central region as per our dataset

# %% [markdown]
# ![pie_chart_2.png](attachment:pie_chart_2.png)

# %% [markdown]
# ---> It depicts the total number of units sold in East region as per our dataset.

# %% [markdown]
# ![pie_chart_3.png](attachment:pie_chart_3.png)

# %% [markdown]
# ---> It depicts the total number of units sold in West region as per our dataset.

# %% [markdown]
# # 4.  Data Visualisation for our file P12OfficeSupplies.csv through -----> Area Chart using the tool or software package Tableau Public.

# %% [markdown]
# ![Area_chart_1.png](attachment:Area_chart_1.png)

# %% [markdown]
# # 5.  Data Visualisation for our file P12OfficeSupplies.csv through -----> Tree Map using the tool or software package Tableau Public.

# %% [markdown]
# ![Tree_Map_chart.png](attachment:Tree_Map_chart.png)

# %% [markdown]
# ---> It depicts the total number of units sold in Central region as per our dataset.

# %% [markdown]
# ![Tree_map_chart_2.png](attachment:Tree_map_chart_2.png)

# %% [markdown]
# ---> It depicts the total number of units sold in East region as per our dataset

# %% [markdown]
# ![Tree_map_chart_3.png](attachment:Tree_map_chart_3.png)

# %% [markdown]
# ---> It depicts the total number of units sold in West region as per our dataset
